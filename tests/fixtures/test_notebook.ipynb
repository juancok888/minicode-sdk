# %% [markdown]
# # Test Notebook
#
# This is a test notebook for ReadTool.

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
x = 42
x
# Out:
# 42

# %% [markdown]
# ## Section 2
#
# Some more text here.

# %%
def add(a, b):
    """Add two numbers."""
    return a + b
